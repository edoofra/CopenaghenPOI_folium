# %%
import folium

# %%
hotel_coords = [55.66972249394334, 12.571001127007971]
m = folium.Map(location=hotel_coords,zoom_start=13)
folium.Marker(location=hotel_coords, popup="Point of interest", icon=folium.Icon(color='red')).add_to(m)


folium.Circle(location=hotel_coords, radius=1000, color='green', opacity=0.5, weight=5).add_to(m)
folium.Circle(location=hotel_coords, radius=2000, color='blue', opacity=0.5, weight=5).add_to(m)
folium.Circle(location=hotel_coords, radius=3000, color='yellow', opacity=0.5, weight=5).add_to(m)
folium.Circle(location=hotel_coords, radius=4000, color='orange', opacity=0.5, weight=5).add_to(m)
folium.Circle(location=hotel_coords, radius=5000, color='red', opacity=0.5, weight=5).add_to(m)



folium.Marker(
    [55.67380508131804, 12.568190013801155], popup="<b>Tivoli</b>",
).add_to(m)

folium.Marker(
    [55.606345613215645, 12.38776344448226], popup="<b>DAC: con scale arcobaleno</b>",
).add_to(m)

folium.Marker(
    [55.67220603835738, 12.57861271380107], popup="<b>:Arken: Museo arte moderna</b>",
).add_to(m)

folium.Marker(
    [55.7269414042921, 12.580153988663865], popup="<b>Experimentarium: Museo scienza</b>",
).add_to(m)

folium.Marker(
    [55.63830202433372, 12.656241157977076], popup="<b>acquario di danimarca</b>",
).add_to(m)

folium.Marker(
    [55.68863238770446, 12.587094040789015], popup="<b>Quartiere Nyboder</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.673372451121786, 12.582007726861935], popup="<b>Den Sorte Diamant: biblioteca reale</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.67669587079179, 12.580337669623999], popup="<b>Christianborg palace</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.69945606373883, 12.54239558496667], popup="<b>Piazza di architettura moderna</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.67565692630838, 12.592565025446698], popup="<b>Christianshavns Kanal</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.68147460419033, 12.57581175797867], popup="<b>Rundertaarn</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.69118959605273, 12.593931913801772], popup="<b>Kastellet</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.68009430542257, 12.590873611953269], popup="<b>Porto</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.67647732341886, 12.575471242636684], popup="<b>Magstraede</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.69854615082114, 12.599210736422751], popup="<b>La sirenetta GM</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.69311397665747, 12.599304257420101], popup="<b>La sirenetta</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.684198451747854, 12.59297817157051], popup="<b>Palazzo di Amalienborg</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.68470390252531, 12.620029398459765], popup="<b>copenHill</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.673582687165144, 12.59643129716061], popup="<b>Christania</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.678798915150615, 12.577479513516066], popup="<b>Stroget: quartiere shopping</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.68509759809101, 12.589660028859852], popup="<b>Marmorkirken station</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.699250770715224, 12.554578929229868], popup="<b>Norrebro </b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.68759882200944, 12.572970140788966], popup="<b>Orto Botanico Copenaghen</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.6893766615399, 12.597539938940907], popup="<b>Fontana di Gefion</b>",icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    [55.68525419099647, 12.579952486814248], popup="<b>Kongens have giardini del re</b>",icon=folium.Icon(color="green"),
).add_to(m)




folium.Marker(
    [55.67963192681935, 12.57569878638094], popup="<b>Sporvejen:tram burger</b>",icon=folium.Icon(color="orange"),
).add_to(m)

folium.Marker(
    [55.69375891960202, 12.608436715649969], popup="<b>Reffen: street food</b>",icon=folium.Icon(color="orange"),
).add_to(m)

folium.Marker(
    [55.67896381312055, 12.576872700307606], popup="<b>Dop: hot dog</b>",icon=folium.Icon(color="orange"),
).add_to(m)

folium.Marker(
    [55.67955175602276, 12.579586601142976], popup="<b>Ilium rooftop cafe economico</b>",icon=folium.Icon(color="orange"),
).add_to(m)

folium.Marker(
    [55.68385318972743, 12.569808413801473], popup="<b>Tornvehallerne mercato street food</b>",icon=folium.Icon(color="orange"),
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save(outfile = "index.html")
